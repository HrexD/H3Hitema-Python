# %%
import pandas as pd
import seaborn as sb
import matplotlib as mpl
import numpy as np

sb.color_palette("tab10")

import csv
df=pd.read_csv(r'.\Twitch_game_data.csv',encoding='cp1252')

# %%
df
# Out:
#        Rank                              Game  Month  Year  Hours_watched  \
# 0         1                 League of Legends      1  2016       94377226
# 1         2  Counter-Strike: Global Offensive      1  2016       47832863
# 2         3                            Dota 2      1  2016       45185893
# 3         4                       Hearthstone      1  2016       39936159
# 4         5       Call of Duty: Black Ops III      1  2016       16153057
# ...     ...                               ...    ...   ...            ...
# 14395   196                       Garry's Mod     12  2021         630902
# 14396   197  Call of Duty: Black Ops Cold War     12  2021         622497
# 14397   198                             Noita     12  2021         620983
# 14398   199                 Pro Soccer Online     12  2021         619859
# 14399   200              Pokemon Sword/Shield     12  2021         615725
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# ...

# %%
df_Game=df.query("Game == 'League of Legends' or  Game == 'Apex Legends' or Game == 'World of Warcraft' or Game=='Fortnite' or Game=='Just Chatting' or Game=='VALORANT'")

# %%
df_Game
# Out:
#        Rank               Game  Month  Year  Hours_watched Hours_Streamed  \
# 0         1  League of Legends      1  2016       94377226  1362044 hours
# 6         7  World of Warcraft      1  2016        8771452   342978 hours
# 200       1  League of Legends      2  2016       93154772  1266715 hours
# 209      10  World of Warcraft      2  2016        6330745   289330 hours
# 400       1  League of Legends      3  2016       94514511  1264029 hours
# ...     ...                ...    ...   ...            ...            ...
# 14202     3           VALORANT     12  2021       98306478  2812461 hours
# 14203     4  League of Legends     12  2021       95180552  2465988 hours
# 14205     6           Fortnite     12  2021       67039763  4833376 hours
# 14208     9       Apex Legends     12  2021       46483936  3100762 hours
# 14214    15  World of Warcraft     12  2021       22373247   777745 hours
#
#        Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# ...

# %%
df_Game_2016=df_Game[df_Game['Year']==2016]

# %%
df_Game_2016
# Out:
#       Rank               Game  Month  Year  Hours_watched Hours_Streamed  \
# 0        1  League of Legends      1  2016       94377226  1362044 hours
# 6        7  World of Warcraft      1  2016        8771452   342978 hours
# 200      1  League of Legends      2  2016       93154772  1266715 hours
# 209     10  World of Warcraft      2  2016        6330745   289330 hours
# 400      1  League of Legends      3  2016       94514511  1264029 hours
# 408      9  World of Warcraft      3  2016        6873120   295301 hours
# 600      1  League of Legends      4  2016       88389049  1217250 hours
# 606      7  World of Warcraft      4  2016        7675362   283609 hours
# 800      1  League of Legends      5  2016       80679320  1196096 hours
# 806      7  World of Warcraft      5  2016        8532283   277450 hours
# 1000     1  League of Legends      6  2016       81348505  1037242 hours
# 1008     9  World of Warcraft      6  2016        7683385   285629 hours
# ...

# %%
sb.barplot(data=df_Game, x="Year", y="Hours_watched", hue="Game" )
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Hours_watched'>

# %%
sb.barplot(data=df_Game_2016, x="Month", y="Hours_watched", hue="Game")
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Hours_watched'>

# %%
sb.barplot(data=df_2017, x="Month", y="Hours_watched",  )
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Hours_watched'>

# %%
sb.barplot(data=df_2018, x="Month", y="Hours_watched",  )
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Hours_watched'>

# %%
sb.barplot(data=df_2019, x="Month", y="Hours_watched",  )
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Hours_watched'>

# %%
sb.barplot(data=df_2020, x="Month", y="Hours_watched",  )
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Hours_watched'>

# %%
sb.boxplot(data=df_2021, x="Month", y="Hours_watched",  )
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Hours_watched'>

# %%
df_lol=df.query("Game == 'League of Legends'")

# %%
sb.lineplot(data=df, x="Year", y="Hours_watched", hue='Game' )
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Hours_watched'>

# %%
df_lol.describe()
# Out:
#             Rank      Month        Year  Hours_watched  Peak_viewers  \
# count  72.000000  72.000000    72.00000   7.200000e+01  7.200000e+01
# mean    1.791667   6.500000  2018.50000   1.034845e+08  6.448662e+05
# std     0.803820   3.476278     1.71981   3.010517e+07  4.891265e+05
# min     1.000000   1.000000  2016.00000   6.821046e+07  2.235710e+05
# 25%     1.000000   3.750000  2017.00000   8.134980e+07  3.489878e+05
# 50%     2.000000   6.500000  2018.50000   9.444587e+07  4.984700e+05
# 75%     2.000000   9.250000  2020.00000   1.221269e+08  7.151865e+05
# max     4.000000  12.000000  2021.00000   2.085748e+08  3.082772e+06
#
#        Peak_channels      Streamers    Avg_viewers  Avg_channels  \
# count      72.000000      72.000000      72.000000     72.000000
# mean     4761.861111  171295.833333  141884.180556   2827.027778
# std      2348.886253   54782.364795   41139.103307   1215.449444
# min      2089.000000   36118.000000   91804.000000   1351.000000
# ...

# %%
sb_2016
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Hours_watched'>

# %%
df_Game_Rank1=df_Game[df_Game['Rank']==1]

# %%
df_Game_Rank1
# Out:
#        Rank               Game  Month  Year  Hours_watched Hours_Streamed  \
# 0         1  League of Legends      1  2016       94377226  1362044 hours
# 200       1  League of Legends      2  2016       93154772  1266715 hours
# 400       1  League of Legends      3  2016       94514511  1264029 hours
# 600       1  League of Legends      4  2016       88389049  1217250 hours
# 800       1  League of Legends      5  2016       80679320  1196096 hours
# ...     ...                ...    ...   ...            ...            ...
# 13400     1      Just Chatting      8  2021      249610555  3255305 hours
# 13600     1      Just Chatting      9  2021      222594651  2982598 hours
# 13800     1      Just Chatting     10  2021      217994303  2945069 hours
# 14000     1      Just Chatting     11  2021      231514981  2828547 hours
# 14200     1      Just Chatting     12  2021      271538951  3116407 hours
#
#        Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# ...

# %%
sb.distplot(a=df_Game['Peak_viewers'])
# Out:
# C:\Users\CGO\AppData\Local\Temp\ipykernel_8808\1634005208.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(a=df_Game['Peak_viewers'])
# <AxesSubplot: xlabel='Peak_viewers', ylabel='Density'>
