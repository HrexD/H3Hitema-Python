# %%
import pandas as pd
#import seaborn as sb
#import numpy as np
import warnings
import streamlit as st

df=pd.read_csv(r'.\Twitch_game_data.csv',encoding='cp1252')
# Out:
#        Rank                              Game  Month  Year  Hours_watched  \
# 0         1                 League of Legends      1  2016       94377226
# 1         2  Counter-Strike: Global Offensive      1  2016       47832863
# 2         3                            Dota 2      1  2016       45185893
# 3         4                       Hearthstone      1  2016       39936159
# 4         5       Call of Duty: Black Ops III      1  2016       16153057
# ...     ...                               ...    ...   ...            ...
# 14395   196                       Garry's Mod     12  2021         630902
# 14396   197  Call of Duty: Black Ops Cold War     12  2021         622497
# 14397   198                             Noita     12  2021         620983
# 14398   199                 Pro Soccer Online     12  2021         619859
# 14399   200              Pokemon Sword/Shield     12  2021         615725
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# ...

# %%
st.line_chart(df.query('Game=="League of Legends" and Year==2020 and Month==12' ))
# Out:
# 2022-10-24 13:20:30.381
# ...
#   command:
#
#     streamlit run c:\Users\CGO\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)
