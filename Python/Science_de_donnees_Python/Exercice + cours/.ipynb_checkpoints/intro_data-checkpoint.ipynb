# %%
import pandas as pd
import seaborn as sb
import matplotlib as mpl
import numpy as np

# %% [markdown]
# # Visualisation d’un nuage de points et exploration des variables

# %%
csv_house = pd.read_csv("./data/house_pricing.csv", sep=',')
print(csv_house.values)
# Out:
# [[1 60 'RL' ... 'WD' 'Normal' 208500]
#  [2 20 'RL' ... 'WD' 'Normal' 181500]
#  [3 60 'RL' ... 'WD' 'Normal' 223500]
#  ...
#  [1458 70 'RL' ... 'WD' 'Normal' 266500]
#  [1459 20 'RL' ... 'WD' 'Normal' 142125]
#  [1460 20 'RL' ... 'WD' 'Normal' 147500]]

# %%
sb.set_theme()
sb.relplot(data=csv_house, x="SalePrice", y="LotArea" )

# %%
csv_house_filtred = csv_house.query('LotArea < 20000 and SalePrice < 500000')
sb.relplot(data=csv_house_filtred,  x="SalePrice", y="LotArea" )

# %%
sb.relplot(data=csv_house, x="LotFrontage", y="LotArea" )

# %%
csv_sales = pd.read_csv("./data/sales_predictions.csv", sep=',')
sb.relplot(data=csv_sales,  x="date", y="item_price")

# %% [markdown]
# # Visualisation de relations continues

# %%
csv_sales_sample = csv_sales.sample(n=50)
sb.relplot(data=csv_sales_sample,  x="date", y="item_price")

# %%
sb.relplot(data=csv_sales_sample,  x="date", y="item_price", sizes=(20, 6))

# %%
sb.relplot(data=csv_sales_sample,  x=pd.to_datetime(csv_sales_sample['date']), y="item_price", sizes=(20, 6))
# Out:
# /tmp/ipykernel_18667/2210533840.py:1: UserWarning: Parsing '21.02.2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sb.relplot(data=csv_sales_sample,  x=pd.to_datetime(csv_sales_sample['date']), y="item_price", sizes=(20, 6))
# /tmp/ipykernel_18667/2210533840.py:1: UserWarning: Parsing '25.11.2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sb.relplot(data=csv_sales_sample,  x=pd.to_datetime(csv_sales_sample['date']), y="item_price", sizes=(20, 6))
# /tmp/ipykernel_18667/2210533840.py:1: UserWarning: Parsing '13.12.2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sb.relplot(data=csv_sales_sample,  x=pd.to_datetime(csv_sales_sample['date']), y="item_price", sizes=(20, 6))
# ...

# %% [markdown]
# # Visualisation de variables catégoriques

# %%
csv_attrition = pd.read_csv('./data/IBM_HR_ATTRITION.csv')
sb.catplot(data=csv_attrition, x='JobSatisfaction', y='Attrition')

# %%
sb.boxplot(data=csv_attrition, x='JobSatisfaction', y='Attrition')
# Out:
# <AxesSubplot: xlabel='JobSatisfaction', ylabel='Attrition'>

# %% [markdown]
# Peut-on dire grâce aux boxplot si une variable présente des valeurs aberrantes ?
# Oui

# %%
csv_attrition_filtred = csv_attrition.query("JobSatisfaction < 2 and Attrition == 'Yes'")

# %%
csv_attrition.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
csv_attrition_filtred.describe()
# Out:
#              Age    DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count  66.000000    66.000000         66.000000  66.000000           66.0
# mean   33.227273   749.651515         10.742424   2.909091            1.0
# std     8.357025   402.390109          8.337700   1.003490            0.0
# min    19.000000   104.000000          1.000000   1.000000            1.0
# 25%    28.250000   372.750000          3.250000   2.000000            1.0
# 50%    32.500000   712.000000          9.000000   3.000000            1.0
# 75%    37.000000  1115.750000         16.000000   4.000000            1.0
# max    58.000000  1475.000000         29.000000   5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count       66.000000                66.000000   66.000000       66.000000
# mean      1085.727273                 2.424242   69.530303        2.545455
# std        565.338906                 1.164350   19.988627        0.727098
# ...

# %%
csv_attrition.compare(csv_attrition_filtred) # WTF
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 csv_attrition.compare(csv_attrition_filtred)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:7202, in DataFrame.compare(self, other, align_axis, keep_shape, keep_equal)
#    7089 @doc(
#    7090     _shared_docs["compare"],
#    7091     """
#    (...)
#    7200     keep_equal: bool = False,
#    7201 ) -> DataFrame:
# -> 7202     return super().compare(
#    7203         other=other,
#    7204         align_axis=align_axis,
#    7205         keep_shape=keep_shape,
#    7206         keep_equal=keep_equal,
#    7207     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:8647, in NDFrame.compare(self, other, align_axis, keep_shape, keep_equal)
#    8642     cls_self, cls_other = type(self).__name__, type(other).__name__
#    8643     raise TypeError(
# ...

# %%
print(csv_attrition['TotalWorkingYears'])
print(csv_attrition_filtred['TotalWorkingYears'])
# Out:
# 0        8
# 1       10
# 2        7
# 3        8
# 4        6
#         ..
# 1465    17
# 1466     9
# 1467     6
# 1468    17
# 1469     6
# Name: TotalWorkingYears, Length: 1470, dtype: int64
# 21      10
# 24       8
# 26      10
# 100      7
# 140     10
#         ..
# 1353     5
# 1365     1
# 1396    15
# 1438     1
# 1461    20
# Name: TotalWorkingYears, Length: 66, dtype: int64

# %%
csv_attrition = csv_attrition.replace(to_replace="Yes", value=1)
csv_attrition = csv_attrition.replace(to_replace="No", value=0)
csv_attrition.values
# Out:
# array([[41, 1, 'Travel_Rarely', ..., 4, 0, 5],
#        [49, 0, 'Travel_Frequently', ..., 7, 1, 7],
#        [37, 1, 'Travel_Rarely', ..., 0, 0, 0],
#        ...,
#        [27, 0, 'Travel_Rarely', ..., 2, 0, 3],
#        [49, 0, 'Travel_Frequently', ..., 6, 0, 8],
#        [34, 0, 'Travel_Rarely', ..., 3, 1, 2]], dtype=object)

# %%
sb.histplot(data=csv_attrition, x="EducationField", y="Attrition")
# Out:
# <AxesSubplot: xlabel='EducationField', ylabel='Attrition'>

# %% [markdown]
# # Visualisation d’une distribution

# %%
sb.distplot(a=csv_attrition['MonthlyIncome'])
# Out:
# /tmp/ipykernel_18667/3242553722.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(a=csv_attrition['MonthlyIncome'])
# <AxesSubplot: xlabel='MonthlyIncome', ylabel='Density'>

# %%
sb.distplot(a=csv_attrition.query('MonthlyIncome >= 0 and MonthlyIncome < 5000')['MonthlyIncome'])
# Out:
# /tmp/ipykernel_18667/3243534627.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(a=csv_attrition.query('MonthlyIncome >= 0 and MonthlyIncome < 5000')['MonthlyIncome'])
# <AxesSubplot: xlabel='MonthlyIncome', ylabel='Density'>

# %% [markdown]
# # Visualisation d’une relation linéaire

# %%
sb.lmplot(data=csv_attrition, x="DistanceFromHome", y="Attrition")

# %%
sb.lmplot(data=csv_attrition, x="YearsWithCurrManager", y="Attrition")

# %% [markdown]
# # Visualisation d’une heatmap

# %%
csv_house = csv_house.iloc[-15:]

# %%
csv_house_corr = csv_house.corr()
print(csv_house_corr)
# Out:
#                          Id  MSSubClass  LotFrontage   LotArea   OverallQual  \
# Id             1.000000e+00   -0.299933     0.170671 -0.176641 -2.820443e-16
# MSSubClass    -2.999333e-01    1.000000    -0.879089 -0.643601 -2.135655e-01
# LotFrontage    1.706710e-01   -0.879089     1.000000  0.914186  2.928409e-01
# LotArea       -1.766413e-01   -0.643601     0.914186  1.000000 -1.544585e-01
# OverallQual   -2.820443e-16   -0.213565     0.292841 -0.154458  1.000000e+00
# OverallCond    1.479836e-01    0.051806    -0.176484  0.150015 -1.694586e-01
# YearBuilt      3.847864e-02    0.052251     0.019051 -0.148001  4.729485e-01
# YearRemodAdd   3.193971e-01   -0.124680     0.211581 -0.204825  3.828724e-01
# MasVnrArea    -3.907955e-01   -0.121045     0.279790  0.251578  5.706548e-01
# BsmtFinSF1    -2.039226e-02    0.098483    -0.049288  0.026653  2.180785e-01
# BsmtFinSF2     2.372469e-01   -0.198927     0.142105 -0.058416 -1.765379e-01
# ...

# %%
sb.heatmap(data=csv_house_corr)
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Formaliser des KPI

# %% [markdown]
# Key Performance Indicator

# %%
csv_resto = pd.read_csv('./data/resto.csv')
csv_resto = csv_resto.iloc[:10]
print(csv_resto.shape)
# Out:
# (10, 6)

# %%
print(csv_resto.head())
# Out:
#    Unnamed: 0  order_id  quantity                              item_name  \
# 0           0         1         1           Chips and Fresh Tomato Salsa
# 1           1         1         1                                   Izze
# 2           2         1         1                       Nantucket Nectar
# 3           3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4           4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
print(csv_resto.groupby('item_name').size())
# Out:
# item_name
# Chicken Bowl                             2
# Chips and Fresh Tomato Salsa             1
# Chips and Tomatillo-Green Chili Salsa    1
# Izze                                     1
# Nantucket Nectar                         1
# Side of Chips                            1
# Steak Burrito                            2
# Steak Soft Tacos                         1
# dtype: int64

# %%
order_count = csv_resto['item_name'].count()
print(order_count)
# Out:
# 10

# %%
ca = csv_resto['item_price'].str[1:].astype(float).sum().round(2)
print(ca)
# Out:
# 71.46

# %%
(ca / order_count).round(2)
# Out:
# 7.15
